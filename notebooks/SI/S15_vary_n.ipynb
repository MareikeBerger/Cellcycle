# %%
import numpy as np
import pandas as pd
import os
from glob import glob
from pprint import pprint
import json
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.pyplot as plt

import cellcycle.PlottingTools as plottingTools
from cellcycle.ParameterSet import ParameterSet
import cellcycle.DataStorage as dataStorage
import cellcycle.DataAnalysis as dataAnalysis
import cellcycle.MakeDataframe as makeDataframe

# %%
version = 'vary_n_low_growth_rate' # options 'vary_n_low_growth_rate' or 'vary_n_high_growth_rate'
file_path = '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/'+ version

parameter_path = os.path.join(file_path, 'parameter_set.csv')

# %%
pinkish_red = (247 / 255, 109 / 255, 109 / 255)
green = (0 / 255, 133 / 255, 86 / 255)
dark_blue = (36 / 255, 49 / 255, 94 / 255)
light_blue = (168 / 255, 209 / 255, 231 / 255)
blue = (55 / 255, 71 / 255, 133 / 255)
yellow = (247 / 255, 233 / 255, 160 / 255)

# %%
v_init_exp = 0.28
std_exp = 0.05

# %%
data_frame = makeDataframe.make_dataframe(file_path)
data_frame = makeDataframe.add_average_values_to_df(data_frame)
data_frame = makeDataframe.add_theoretical_init_reg_concentrations_to_df(data_frame)
data_frame
# Out:
# ['/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/Fig_total_conc.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/basal_3000_block_low',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/low_basal_2000_blocked',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/init_volume_vary_n_sites.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/basal_4000_blocked_low',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/init_volume_vary_n_sites_low_not_blocked.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/Fig_3D.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/init_volume_vary_n_sites_with_blocked.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/init_volume_vary_n_sites_low2.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/SI/S15_titration_switch_combined_vary_n_sites/vary_n_low_growth_rate/Fig_amplitude_free_active_conc.pdf']
#     amplitude_oscillations  aspect_ratio  basal_rate_initiator  \
# 0                     10.0           4.0            519.860385
# 1                     10.0           4.0            519.860385
# 2                     10.0           4.0            519.860385
# 3                     10.0           4.0            519.860385
# 4                     10.0           4.0            519.860385
# 5                     10.0           4.0            519.860385
# 6                     10.0           4.0            519.860385
# 7                     10.0           4.0            519.860385
# 8                     10.0           4.0            519.860385
# 9                     10.0           4.0            519.860385
# 10                    10.0           4.0            519.860385
# 11                    10.0           4.0            519.860385
# 12                    10.0           4.0            519.860385
# 13                    10.0           4.0            519.860385
# 14                    10.0           4.0            519.860385
# 15                    10.0           4.0            346.573590
# 16                    10.0           4.0            346.573590
# 17                    10.0           4.0            346.573590
# 18                    10.0           4.0            346.573590
# 19                    10.0           4.0            346.573590
# 20                    10.0           4.0            346.573590
# 21                    10.0           4.0            346.573590
# 22                    10.0           4.0            346.573590
# 23                    10.0           4.0            346.573590
# 24                    10.0           4.0            346.573590
# 25                    10.0           4.0            346.573590
# 26                    10.0           4.0            346.573590
# 27                    10.0           4.0            346.573590
# 28                    10.0           4.0            346.573590
# 29                    10.0           4.0            346.573590
# 30                    10.0           4.0            693.147181
# 31                    10.0           4.0            693.147181
# 32                    10.0           4.0            693.147181
# 33                    10.0           4.0            693.147181
# 34                    10.0           4.0            693.147181
# 35                    10.0           4.0            693.147181
# 36                    10.0           4.0            693.147181
# 37                    10.0           4.0            693.147181
# 38                    10.0           4.0            693.147181
# 39                    10.0           4.0            693.147181
# 40                    10.0           4.0            693.147181
# 41                    10.0           4.0            693.147181
# 42                    10.0           4.0            693.147181
# 43                    10.0           4.0            693.147181
# 44                    10.0           4.0            693.147181
#
#     basal_rate_initiator_0  basal_rate_regulator  basal_rate_regulator_0  \
# 0                   3000.0             12.130076                    70.0
# 1                   3000.0             12.130076                    70.0
# 2                   3000.0             12.130076                    70.0
# 3                   3000.0             12.130076                    70.0
# 4                   3000.0             12.130076                    70.0
# 5                   3000.0             12.130076                    70.0
# 6                   3000.0             12.130076                    70.0
# 7                   3000.0             12.130076                    70.0
# 8                   3000.0             12.130076                    70.0
# 9                   3000.0             12.130076                    70.0
# 10                  3000.0             12.130076                    70.0
# 11                  3000.0             12.130076                    70.0
# 12                  3000.0             12.130076                    70.0
# 13                  3000.0             12.130076                    70.0
# 14                  3000.0             12.130076                    70.0
# 15                  2000.0             12.130076                    70.0
# 16                  2000.0             12.130076                    70.0
# 17                  2000.0             12.130076                    70.0
# 18                  2000.0             12.130076                    70.0
# 19                  2000.0             12.130076                    70.0
# 20                  2000.0             12.130076                    70.0
# 21                  2000.0             12.130076                    70.0
# 22                  2000.0             12.130076                    70.0
# 23                  2000.0             12.130076                    70.0
# 24                  2000.0             12.130076                    70.0
# 25                  2000.0             12.130076                    70.0
# 26                  2000.0             12.130076                    70.0
# 27                  2000.0             12.130076                    70.0
# 28                  2000.0             12.130076                    70.0
# 29                  2000.0             12.130076                    70.0
# 30                  4000.0             12.130076                    70.0
# 31                  4000.0             12.130076                    70.0
# 32                  4000.0             12.130076                    70.0
# 33                  4000.0             12.130076                    70.0
# 34                  4000.0             12.130076                    70.0
# 35                  4000.0             12.130076                    70.0
# 36                  4000.0             12.130076                    70.0
# 37                  4000.0             12.130076                    70.0
# 38                  4000.0             12.130076                    70.0
# 39                  4000.0             12.130076                    70.0
# 40                  4000.0             12.130076                    70.0
# 41                  4000.0             12.130076                    70.0
# 42                  4000.0             12.130076                    70.0
# 43                  4000.0             12.130076                    70.0
# 44                  4000.0             12.130076                    70.0
#
#     block_production                                          code_path  \
# 0                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 1                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 2                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 3                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 4                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 5                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 6                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 7                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 8                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 9                  1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 10                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 11                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 12                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 13                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 14                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 15                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 16                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 17                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 18                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 19                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 20                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 21                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 22                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 23                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 24                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 25                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 26                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 27                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 28                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 29                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 30                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 31                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 32                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 33                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 34                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 35                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 36                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 37                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 38                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 39                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 40                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 41                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 42                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 43                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
# 44                 1  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...
#
#     conc_0  continuous_oscillations  ...    version_of_titration  \
# 0    400.0                        1  ...  regulator_is_initiator
# 1    400.0                        1  ...  regulator_is_initiator
# 2    400.0                        1  ...  regulator_is_initiator
# 3    400.0                        1  ...  regulator_is_initiator
# 4    400.0                        1  ...  regulator_is_initiator
# 5    400.0                        1  ...  regulator_is_initiator
# 6    400.0                        1  ...  regulator_is_initiator
# 7    400.0                        1  ...  regulator_is_initiator
# 8    400.0                        1  ...  regulator_is_initiator
# 9    400.0                        1  ...  regulator_is_initiator
# 10   400.0                        1  ...  regulator_is_initiator
# 11   400.0                        1  ...  regulator_is_initiator
# 12   400.0                        1  ...  regulator_is_initiator
# 13   400.0                        1  ...  regulator_is_initiator
# 14   400.0                        1  ...  regulator_is_initiator
# 15   400.0                        1  ...  regulator_is_initiator
# 16   400.0                        1  ...  regulator_is_initiator
# 17   400.0                        1  ...  regulator_is_initiator
# 18   400.0                        1  ...  regulator_is_initiator
# 19   400.0                        1  ...  regulator_is_initiator
# 20   400.0                        1  ...  regulator_is_initiator
# 21   400.0                        1  ...  regulator_is_initiator
# 22   400.0                        1  ...  regulator_is_initiator
# 23   400.0                        1  ...  regulator_is_initiator
# 24   400.0                        1  ...  regulator_is_initiator
# 25   400.0                        1  ...  regulator_is_initiator
# 26   400.0                        1  ...  regulator_is_initiator
# 27   400.0                        1  ...  regulator_is_initiator
# 28   400.0                        1  ...  regulator_is_initiator
# 29   400.0                        1  ...  regulator_is_initiator
# 30   400.0                        1  ...  regulator_is_initiator
# 31   400.0                        1  ...  regulator_is_initiator
# 32   400.0                        1  ...  regulator_is_initiator
# 33   400.0                        1  ...  regulator_is_initiator
# 34   400.0                        1  ...  regulator_is_initiator
# 35   400.0                        1  ...  regulator_is_initiator
# 36   400.0                        1  ...  regulator_is_initiator
# 37   400.0                        1  ...  regulator_is_initiator
# 38   400.0                        1  ...  regulator_is_initiator
# 39   400.0                        1  ...  regulator_is_initiator
# 40   400.0                        1  ...  regulator_is_initiator
# 41   400.0                        1  ...  regulator_is_initiator
# 42   400.0                        1  ...  regulator_is_initiator
# 43   400.0                        1  ...  regulator_is_initiator
# 44   400.0                        1  ...  regulator_is_initiator
#
#     average_init_conc  average_init_conc_normalized  average_volume  \
# 0          458.135036                      1.145338        0.178486
# 1         1323.917925                      3.309795        0.251609
# 2         1345.542941                      3.363857        0.285468
# 3         1158.128144                      2.895320        0.208295
# 4         1368.218371                      3.420546        0.594092
# 5         1360.736482                      3.401841        0.359319
# 6         1364.356010                      3.410890        0.396226
# 7         1366.261829                      3.415655        0.433859
# 8         1368.450544                      3.421126        0.552751
# 9         1271.893599                      3.179734        0.224385
# 10        1355.037387                      3.387593        0.322254
# 11        1367.962906                      3.419907        0.512209
# 12         970.229133                      2.425573        0.201758
# 13         727.737656                      1.819344        0.195311
# 14        1367.222632                      3.418057        0.472505
# 15         414.311678                      1.035779        0.193378
# 16         906.887868                      2.267220        0.371669
# 17         909.320299                      2.273301        0.433409
# 18         880.577419                      2.201444        0.261250
# 19         911.857077                      2.279643        0.972387
# 20         911.117901                      2.277795        0.562745
# 21         911.470133                      2.278675        0.629976
# 22         911.541535                      2.278854        0.698088
# 23         911.795013                      2.279488        0.903691
# 24         900.701142                      2.251753        0.312703
# 25         910.425279                      2.276063        0.497047
# 26         911.612343                      2.279031        0.835115
# 27         809.172791                      2.022932        0.226927
# 28         643.653413                      1.609134        0.211283
# 29         911.564055                      2.278910        0.766571
# 30         488.395354                      1.220988        0.170351
# 31        1643.493798                      4.108734        0.207279
# 32        1724.745069                      4.311863        0.224284
# 33        1301.508240                      3.253771        0.194986
# 34        1823.606076                      4.559015        0.432763
# 35        1787.639056                      4.469098        0.272363
# 36        1801.534686                      4.503837        0.298698
# 37        1810.417477                      4.526044        0.324901
# 38        1822.635131                      4.556588        0.404930
# 39        1502.398236                      3.755996        0.197921
# 40        1766.430661                      4.416077        0.246790
# 41        1819.882082                      4.549705        0.377799
# 42        1054.101733                      2.635254        0.193277
# 43         778.717075                      1.946793        0.187413
# 44        1816.590032                      4.541475        0.351107
#
#     average_n_ori v_init_per_n_ori    v_init  average_reg_conc_th  \
# 0        1.500775         0.174905  0.174905           181.729092
# 1        1.501025         0.246512  0.246512           158.760822
# 2        1.501025         0.279650  0.279650           149.351623
# 3        1.501025         0.204090  0.204090           171.818001
# 4        1.500925         0.582038  0.582038            87.063644
# 5        1.500925         0.351998  0.351998           130.654695
# 6        1.500925         0.388131  0.388131           122.184206
# 7        1.501025         0.424920  0.424920           114.169077
# 8        1.501025         0.541376  0.541376            93.019870
# 9        1.501025         0.219875  0.219875           166.808933
# 10       1.500875         0.315709  0.315709           139.740535
# 11       1.501025         0.501640  0.501640            99.529530
# 12       1.500825         0.197662  0.197662           173.907454
# 13       1.500775         0.191394  0.191394           176.014530
# 14       1.501025         0.462730  0.462730           106.600178
# 15       1.500775         0.189480  0.189480           176.655174
# 16       1.500925         0.364030  0.364030           127.755113
# 17       1.501025         0.424479  0.424479           114.261402
# 18       1.501025         0.255912  0.255912           156.019868
# 19       1.501025         0.952794  0.952794            53.950669
# 20       1.501025         0.551220  0.551220            91.520177
# 21       1.500925         0.617141  0.617141            82.409146
# 22       1.500875         0.683800  0.683800            74.706008
# 23       1.501025         0.885310  0.885310            58.015636
# 24       1.500925         0.306333  0.306333           142.179408
# 25       1.501025         0.486911  0.486911           102.146395
# 26       1.501025         0.818057  0.818057            62.718320
# 27       1.501025         0.222327  0.222327           166.036194
# 28       1.501025         0.207010  0.207010           170.871580
# 29       1.500875         0.750863  0.750863            68.211973
# 30       1.500825         0.166911  0.166911           184.618793
# 31       1.501025         0.203102  0.203102           172.141376
# 32       1.501025         0.219723  0.219723           166.839761
# 33       1.500825         0.191063  0.191063           176.123997
# 34       1.501025         0.423891  0.423891           114.393725
# 35       1.501025         0.266870  0.266870           152.923193
# 36       1.500925         0.292637  0.292637           145.823424
# 37       1.500875         0.318345  0.318345           139.072282
# 38       1.500975         0.396697  0.396697           120.275656
# 39       1.500825         0.193931  0.193931           175.157839
# 40       1.501025         0.241774  0.241774           160.150956
# 41       1.500925         0.370007  0.370007           126.340011
# 42       1.500875         0.189349  0.189349           176.692870
# 43       1.500775         0.183662  0.183662           178.657116
# 44       1.500925         0.343920  0.343920           132.618378
#
#     average_init_conc_th  average_init_conc_th_normalized
# 0           12373.034360                        30.932586
# 1            8861.291049                        22.153228
# 2            7830.350463                        19.575876
# 3           10653.600039                        26.634000
# 4            3787.778929                         9.469447
# 5            6242.505159                        15.606263
# 6            5667.014346                        14.167536
# 7            5179.743845                        12.949360
# 8            4070.559033                        10.176398
# 9            9909.262382                        24.773156
# 10           6949.972771                        17.374932
# 11           4391.554809                        10.978887
# 12          10987.445212                        27.468613
# 13          11338.983023                        28.347458
# 14           4758.708379                        11.896771
# 15           7632.620520                        19.081551
# 16           4024.965850                        10.062415
# 17           3456.728461                         8.641821
# 18           5694.141372                        14.235353
# 19           1543.580521                         3.858951
# 20           2665.657398                         6.664143
# 21           2381.629290                         5.954073
# 22           2149.489757                         5.373724
# 23           1660.887477                         4.152219
# 24           4772.756749                        11.931892
# 25           3016.611716                         7.541529
# 26           1797.216047                         4.493040
# 27           6534.048700                        16.335122
# 28           7004.695394                        17.511738
# 29           1957.625050                         4.894063
# 30          17258.938982                        43.147347
# 31          14272.444205                        35.681111
# 32          13218.151936                        33.045380
# 33          15143.556131                        37.858890
# 34           6923.691547                        17.309229
# 35          10932.946632                        27.332367
# 36           9985.489288                        24.963723
# 37           9192.265671                        22.980664
# 38           7395.319585                        18.488299
# 39          14925.613439                        37.314034
# 40          12040.536352                        30.101341
# 41           7920.732904                        19.801832
# 42          15273.927478                        38.184819
# 43          15736.035323                        39.340088
# 44           8515.559981                        21.288900
#
# [45 rows x 128 columns]

# %% [markdown]
# # Calculate initiation volume theoretically

# %%
def calculate_v_initi_no_overlap_switch_time_varying(df):
    try:
#         print(df.production_rate_dars1)
        production_rate_dars1 = df.production_rate_dars1
    except:
        production_rate_dars1 = 0
    return df.destruction_rate_datA / df.production_rate_lipids * df.frac_init * \
           (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
           ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))-((production_rate_dars1+ df.production_rate_dars2)/df.production_rate_lipids)

def calculate_v_initi_overlap_switch_time_varying(df):
    try:
#         print(df.production_rate_dars1)
        production_rate_dars1 = df.production_rate_dars1
    except:
        production_rate_dars1 = 0
    return (df.destruction_rate_datA + df.high_rate_datA + df.destruction_rate_rida) / df.production_rate_lipids * df.frac_init * \
           (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
           ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))- \
           ((production_rate_dars1 + df.production_rate_dars2 + df.high_rate_dars2)/df.production_rate_lipids)

data_frame["v_init_per_n_ori_th_no_time_varying"] = data_frame.apply(lambda row: calculate_v_initi_no_overlap_switch_time_varying(row), axis=1)
data_frame["v_init_per_n_ori_th_o_time_varying"] = data_frame.apply(lambda row: calculate_v_initi_no_overlap_switch_time_varying(row), axis=1)

# %%
def calculate_v_init_switch_synthesis(df):
    if df.include_synthesis==0:
        return df.destruction_rate_datA / df.production_rate_lipids * df.frac_init * \
               (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
               ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))
    else:
        return (df.destruction_rate_datA/df.total_conc) * \
                df.frac_init / (df.michaelis_const_destr/df.total_conc+ df.frac_init) * \
                (df.michaelis_const_prod / df.total_conc + 1 - df.frac_init) / \
                ((1- df.frac_init) * \
                (df.production_rate_lipids/df.total_conc + df.rate_growth * (df.michaelis_const_prod / df.total_conc + 1 - df.frac_init)))
    
data_frame["v_init_per_n_ori_synthesis"] = data_frame.apply(lambda row: calculate_v_init_switch_synthesis(row), axis=1)

# %% [markdown]
# # Calculate CV

# %%
for simu_name in data_frame.simu_name.unique():
    simu_df = data_frame[data_frame["simu_name"] == simu_name]
    data_frame.loc[data_frame['simu_name'] == simu_name, 'mean_v_init_per_n_ori'] = np.mean(simu_df["v_init_per_n_ori"])
    data_frame.loc[data_frame['simu_name'] == simu_name, 'stdd_v_init_per_n_ori'] = np.std(simu_df["v_init_per_n_ori"])
    data_frame.loc[data_frame['simu_name'] == simu_name, 'cv_v_init_per_n_ori'] = np.std(simu_df["v_init_per_n_ori"])/np.mean(simu_df["v_init_per_n_ori"])

# %% [markdown]
# # Make Legends

# %%
def make_production_rate_datA_lipids_cv_legend(destruction_rate_datA, production_rate_lipids, cv):
    return r'$\beta_{{\rm datA}}={}$ /h, $\alpha_{{\rm lipids}}={}$ /h, CV= {}'.format(np.round(destruction_rate_datA,3), 
                                                                                       np.round(production_rate_lipids,3), 
                                                                                       np.round(cv,3))

def make_production_rate_datA_cv_legend(destruction_rate_datA, cv):
    return r'$\beta_{{\rm datA}}={}$ /h, CV= {}'.format(np.round(destruction_rate_datA,3),
                                                        np.round(cv,3))

def make_production_rate_datA_legend(destruction_rate_datA):
    return r'$\beta_{{\rm datA}}={}$ min$^{{-1}}$'.format(int(destruction_rate_datA/60))

def make_production_rate_datA_lipids_legend(destruction_rate_datA, production_rate_lipids):
    return r'$\beta_{{\rm datA}}={}$ /h, \linebreak  $\alpha_{{\rm lipids}}={}$ /h'.format(np.round(destruction_rate_datA,3), 
                                                                                       np.round(production_rate_lipids,3))

def make_theoretical_v_init_legend(v_init_per_n_ori_th_no_time_varying):
    return r'$v^\ast_{{\rm th}}={} \, \mu $m$^3$'.format(np.round(v_init_per_n_ori_th_no_time_varying,3))

def make_basal_rate_legend(basal_rate_initiator_0):
    return r'$\phi_0={} \times 10^{{-3}}$'.format(np.round(basal_rate_initiator_0/1000,2))

def make_hill_legend(hill_coeff_initiator):
    return r'$n={}$'.format(int(hill_coeff_initiator))

def make_doubling_rate_legend(doubling_rate):
    return r'$1/\tau_{{\rm d}}={}$'.format(doubling_rate)


def make_blocked_legend(block_production, period_blocked):
    if block_production == 1:
        return r'$\tau_{{\rm b}}={}$'.format(int(period_blocked * 60))
    else:
        return r'$\tau_{{\rm b}}={}$'.format(0)

data_frame.loc[:, 'legend_datA_lipids_cv'] = data_frame.apply(lambda row: make_production_rate_datA_lipids_cv_legend(row.destruction_rate_datA,
                                                                                                              row.production_rate_lipids,
                                                                                                              row.cv_v_init_per_n_ori), axis = 1)

data_frame.loc[:, 'legend_datA_cv'] = data_frame.apply(lambda row: make_production_rate_datA_cv_legend(row.destruction_rate_datA,
                                                                                                              row.cv_v_init_per_n_ori), axis = 1)

data_frame.loc[:, 'legend_datA'] = data_frame.apply(lambda row: make_production_rate_datA_legend(row.destruction_rate_datA), axis = 1)

data_frame.loc[:, 'legend_datA_lipids'] = data_frame.apply(lambda row: make_production_rate_datA_lipids_legend(row.destruction_rate_datA,
                                                                                                              row.production_rate_lipids), axis = 1)

data_frame.loc[:, 'legend_v_init_th'] = data_frame.apply(lambda row: make_theoretical_v_init_legend(row.v_init_per_n_ori_th_no_time_varying), axis = 1)
data_frame.loc[:, 'gene allocation fraction:'] = data_frame.apply(lambda row: make_basal_rate_legend(row.basal_rate_initiator_0), axis = 1)
data_frame.loc[:, 'legend_hill'] = data_frame.apply(lambda row: make_hill_legend(row.hill_coeff_initiator), axis = 1)
data_frame.loc[:, 'legend_doubling_rate'] = data_frame.apply(lambda row: make_doubling_rate_legend(row.doubling_rate), axis = 1)
data_frame.loc[:, 'blocked period:'] = data_frame.apply(lambda row: make_blocked_legend(row.block_production, row.period_blocked), axis = 1)

# %% [markdown]
# # Determine minimal activator fraction

# %%
def determine_min_frac(filepath_h5):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_fraction']
    return np.min(fractions[int(fractions.size/2):])

def determine_max_frac(filepath_h5):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_fraction']
    return np.max(fractions[int(fractions.size/2):])

data_frame.loc[:, 'min_frac'] = data_frame.apply(lambda row: determine_min_frac(row.path_dataset), axis = 1)
data_frame.loc[:, 'max_frac'] = data_frame.apply(lambda row: determine_max_frac(row.path_dataset), axis = 1)
data_frame['amplitude_frac'] = data_frame['max_frac']-data_frame['min_frac']
data_frame['relative_change_frac']= data_frame['min_frac']/data_frame['max_frac']

# %% [markdown]
# # Determine amplitude free active conc

# %%
def determine_min_free_active_conc(filepath_h5):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_fraction']
    free_conc = data_frame_traces['free_conc']
    return np.min(fractions[int(fractions.size/2):] * free_conc[int(free_conc.size/2):])

def determine_max_free_active_conc(filepath_h5):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_fraction']
    free_conc = data_frame_traces['free_conc']
    return np.max(fractions[int(fractions.size/2):] * free_conc[int(free_conc.size/2):])

data_frame.loc[:, 'min_free_active_conc'] = data_frame.apply(lambda row: determine_min_free_active_conc(row.path_dataset), axis = 1)
data_frame.loc[:, 'max_free_active_conc'] = data_frame.apply(lambda row: determine_max_free_active_conc(row.path_dataset), axis = 1)
data_frame['amplitude_free_active_conc'] = data_frame['max_free_active_conc']-data_frame['min_free_active_conc']
data_frame['amplitude_free_active_conc_relative']= data_frame['amplitude_free_active_conc']/data_frame['critical_free_active_conc']

# %% [markdown]
# # Plot initiation volume per origin

# %%
sns.set(style="ticks")
sns.set_context("poster")

data_frame_sorted_1 = data_frame.sort_values(by=["basal_rate_initiator"], ascending=True)
data_frame_sorted_2 = data_frame_sorted_1.sort_values(by=["period_blocked"], ascending=True)

fig, ax = plt.subplots(figsize=(7,7))
sns.lineplot(
    x='n_c_max_0', 
    y='v_init_per_n_ori',
    data= data_frame_sorted_2.sort_values(by=["period_blocked"], ascending=True),
#     hue='blocked period:',
    hue='gene allocation fraction:',
#     style= 'blocked period:',
    palette= [blue, pinkish_red, yellow],
    linewidth = 3.5,
    ax=ax
);
ax.lines[0].set_linestyle("--")
ax.lines[1].set_linestyle("--")
ax.lines[2].set_linestyle("--")
# ax.lines[3].set_linestyle("--")
ax.margins(0)

ax.axvline(x=100, color='grey', linestyle='dotted')
ax.axvline(x=500, color='grey', linestyle='dotted')


ax.set(xlabel=r'$n_s$', ylabel=r'$v^\ast$ [$\mu$m$^3$]')
ax.set(ylim=(0,1))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles=handles[1:], labels=labels[1:])
# ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.savefig(file_path + '/init_volume_vary_n_sites.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# # Plot amplitude free conc time varying

# %%
sns.set(style="ticks")
sns.set_context("poster")


data_frame_sorted_1 = data_frame.sort_values(by=["basal_rate_initiator"], ascending=True)
data_frame_sorted_2 = data_frame_sorted_1.sort_values(by=["block_production"], ascending=True) 

fig, ax = plt.subplots(figsize=(7,7))
sns.lineplot(
    x='n_c_max_0', 
    y='amplitude_free_active_conc_relative',
    data= data_frame_sorted_2.sort_values(by=["basal_rate_initiator"], ascending=True),
    hue='gene allocation fraction:',
#     style= 'blocked period:',
    palette= [blue, pinkish_red, yellow],
    linewidth = 3.5,
    ax=ax
);
ax.lines[0].set_linestyle("--")
ax.lines[1].set_linestyle("--")
ax.lines[2].set_linestyle("--")
ax.lines[3].set_linestyle("--")
ax.margins(0)
ax.set(xlabel=r'$n_s$', ylabel=r' $\Delta [D]_{\rm ATP, f} = [D]_{\rm ATP, f}^\ast - [D]_{\rm ATP, f}^{\rm min}$')
# plt.legend(labels=legend
# ax.set(ylim=(0,0.75))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.savefig(file_path + '/Fig_amplitude_free_active_conc.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# # Plot amplitude fraction

# %%
sns.set(style="ticks")
sns.set_context("poster")

fig, ax = plt.subplots(figsize=(7,7))
sns.lineplot(
    x='n_c_max_0', 
    y='amplitude_frac',
    data=data_frame.sort_values(by=["basal_rate_initiator"], ascending=True),
    hue='gene allocation fraction:',
    style= 'blocked period:',
    palette= [blue, pinkish_red, yellow],
    linewidth = 3.5,
    ax=ax
);

# ax.lines[0].set_linestyle("--")
# ax.lines[1].set_linestyle("--")
# ax.lines[2].set_linestyle("--")
# ax.lines[3].set_linestyle("--")
ax.margins(0)
ax.set(xlabel=r'$n_s$', ylabel=r'$\Delta f = f^\ast-f_{\rm min}$')
# plt.legend(labels=legend
ax.set(ylim=(0,0.75))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.savefig(file_path + '/Fig_3D.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# # Average total concentration

# %%
def make_total_conc(expressed_explicitly, tota_conc, average_init_conc):
    return average_init_conc

data_frame.loc[:, 'total_conc_plot'] = data_frame.apply(lambda row: 
                                                        make_total_conc(row.initiator_explicitly_expressed, 
                                                                                    row.total_conc, 
                                                                                    row.average_init_conc), 
                                                        axis = 1)

# %%
sns.set(style="ticks")
sns.set_context("poster")

fig, ax = plt.subplots(figsize=(7,7))
sns.lineplot(
    x='n_c_max_0', 
    y='total_conc_plot',
    data=data_frame.sort_values(by=["basal_rate_initiator"], ascending=True),
    hue='gene allocation fraction:',
    style= 'blocked period:',
    palette= [blue, pinkish_red, yellow],
    linewidth = 3.5,
    ax=ax
);
# sns.lineplot(
#     x='rate_growth', 
#     y='amplitude_frac',
#     data=data_frame.sort_values(by=["destruction_rate_datA"], ascending=False),
#     hue='legend_datA',
#     dashes=[(4, 1), (4, 1), (4, 1), (4, 1)],
#     markers=True,
#     palette= [green, blue,  pinkish_red], # yellow],
#     linewidth = 3.5,
#     ax=ax
# );
# ax.lines[0].set_linestyle("--")
# ax.lines[1].set_linestyle("--")
# ax.lines[2].set_linestyle("--")
# ax.lines[3].set_linestyle("--")
ax.margins(0)
ax.set(xlabel=r'$n_s$', ylabel=r'$[p]_{\rm T}$')
# plt.legend(labels=legend
ax.set(ylim=(0,2300))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
ax.legend(bbox_to_anchor=(1.1, 1.05))
plt.savefig(file_path + '/Fig_total_conc.pdf', format='pdf', bbox_inches='tight')
