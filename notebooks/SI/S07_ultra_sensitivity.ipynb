# %%
import numpy as np
import pandas as pd
import os
from glob import glob
from pprint import pprint
import json
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.pyplot as plt

import cellcycle.PlottingTools as plottingTools
from cellcycle.ParameterSet import ParameterSet
import cellcycle.DataStorage as dataStorage
import cellcycle.DataAnalysis as dataAnalysis
import cellcycle.MakeDataframe as makeDataframe
from cellcycle import mainClass

# %%
file_path_input_params_json = '../../input_params.json'
input_param_dict = mainClass.extract_variables_from_input_params_json(file_path_input_params_json)
root_path = input_param_dict["DATA_FOLDER_PATH"]
simulation_location = 'SI/S7_LD_ultra_sensitive'
file_path = os.path.join(root_path, simulation_location)
print('file_path', file_path)
parameter_path = os.path.join(file_path, 'parameter_set.csv')
print('parameter_path', parameter_path)
# Out:
# file_path /home/berger/Data/UltrasensitivityCombined/Final_NatCom_Submission/SI/S7_LD_ultra_sensitive
# parameter_path /home/berger/Data/UltrasensitivityCombined/Final_NatCom_Submission/SI/S7_LD_ultra_sensitive/parameter_set.csv

# %%
pinkish_red = (247 / 255, 109 / 255, 109 / 255)
green = (0 / 255, 133 / 255, 86 / 255)
dark_blue = (36 / 255, 49 / 255, 94 / 255)
light_blue = (168 / 255, 209 / 255, 231 / 255)
blue = (55 / 255, 71 / 255, 133 / 255)
yellow = (247 / 255, 233 / 255, 160 / 255)

# %%
v_init_exp = 0.28
std_exp = 0.05

# %%
data_frame = makeDataframe.make_dataframe(file_path)
data_frame = makeDataframe.add_average_values_to_df(data_frame)
data_frame = makeDataframe.add_theoretical_init_reg_concentrations_to_df(data_frame)
data_frame
# Out:
# ['/home/berger/Data/UltrasensitivityCombined/Final_NatCom_Submission/SI/S7_LD_ultra_sensitive/LD_ultra_sens_10',
#  '/home/berger/Data/UltrasensitivityCombined/Final_NatCom_Submission/SI/S7_LD_ultra_sensitive/LD_ultra_sens_100',
#  '/home/berger/Data/UltrasensitivityCombined/Final_NatCom_Submission/SI/S7_LD_ultra_sensitive/rate_comparison.pdf',
#  '/home/berger/Data/UltrasensitivityCombined/Final_NatCom_Submission/SI/S7_LD_ultra_sensitive/Fig_S5_v_init.pdf',
#  '/home/berger/Data/UltrasensitivityCombined/Final_NatCom_Submission/SI/S7_LD_ultra_sensitive/LD_ultra_sens_20',
#  '/home/berger/Data/UltrasensitivityCombined/Final_NatCom_Submission/SI/S7_LD_ultra_sensitive/Fig_S5_fraction.pdf']
#     aspect_ratio  basal_rate_initiator  basal_rate_lipids  \
# 0            4.0                 500.0            50000.0
# 1            4.0                 500.0            50000.0
# 2            4.0                 500.0            50000.0
# 3            4.0                 500.0            50000.0
# 4            4.0                 500.0            50000.0
# 5            4.0                 500.0            50000.0
# 6            4.0                 500.0            50000.0
# 7            4.0                 500.0            50000.0
# 8            4.0                 500.0            50000.0
# 9            4.0                 500.0            50000.0
# 10           4.0                 500.0            50000.0
# 11           4.0                 500.0            50000.0
# 12           4.0                 500.0            50000.0
# 13           4.0                 500.0            50000.0
# 14           4.0                 500.0            50000.0
# 15           4.0                 500.0            50000.0
# 16           4.0                 500.0            50000.0
# 17           4.0                 500.0            50000.0
# 18           4.0                 500.0            50000.0
# 19           4.0                 500.0            50000.0
# 20           4.0                 500.0            50000.0
# 21           4.0                 500.0            50000.0
# 22           4.0                 500.0            50000.0
# 23           4.0                 500.0            50000.0
# 24           4.0                 500.0            50000.0
# 25           4.0                 500.0            50000.0
# 26           4.0                 500.0            50000.0
# 27           4.0                 500.0            50000.0
# 28           4.0                 500.0            50000.0
# 29           4.0                 500.0            50000.0
# 30           4.0                 500.0            50000.0
# 31           4.0                 500.0            50000.0
# 32           4.0                 500.0            50000.0
# 33           4.0                 500.0            50000.0
# 34           4.0                 500.0            50000.0
# 35           4.0                 500.0            50000.0
# 36           4.0                 500.0            50000.0
# 37           4.0                 500.0            50000.0
# 38           4.0                 500.0            50000.0
# 39           4.0                 500.0            50000.0
# 40           4.0                 500.0            50000.0
# 41           4.0                 500.0            50000.0
# 42           4.0                 500.0            50000.0
# 43           4.0                 500.0            50000.0
# 44           4.0                 500.0            50000.0
# 45           4.0                 500.0            50000.0
# 46           4.0                 500.0            50000.0
# 47           4.0                 500.0            50000.0
# 48           4.0                 500.0            50000.0
# 49           4.0                 500.0            50000.0
# 50           4.0                 500.0            50000.0
# 51           4.0                 500.0            50000.0
# 52           4.0                 500.0            50000.0
# 53           4.0                 500.0            50000.0
# 54           4.0                 500.0            50000.0
# 55           4.0                 500.0            50000.0
# 56           4.0                 500.0            50000.0
# 57           4.0                 500.0            50000.0
# 58           4.0                 500.0            50000.0
# 59           4.0                 500.0            50000.0
#
#     basal_rate_regulator  basal_rate_regulator_lipids  block_production  \
# 0                  500.0                      60000.0                 0
# 1                  500.0                      60000.0                 0
# 2                  500.0                      60000.0                 0
# 3                  500.0                      60000.0                 0
# 4                  500.0                      60000.0                 0
# 5                  500.0                      60000.0                 0
# 6                  500.0                      60000.0                 0
# 7                  500.0                      60000.0                 0
# 8                  500.0                      60000.0                 0
# 9                  500.0                      60000.0                 0
# 10                 500.0                      60000.0                 0
# 11                 500.0                      60000.0                 0
# 12                 500.0                      60000.0                 0
# 13                 500.0                      60000.0                 0
# 14                 500.0                      60000.0                 0
# 15                 500.0                      60000.0                 0
# 16                 500.0                      60000.0                 0
# 17                 500.0                      60000.0                 0
# 18                 500.0                      60000.0                 0
# 19                 500.0                      60000.0                 0
# 20                 500.0                      60000.0                 0
# 21                 500.0                      60000.0                 0
# 22                 500.0                      60000.0                 0
# 23                 500.0                      60000.0                 0
# 24                 500.0                      60000.0                 0
# 25                 500.0                      60000.0                 0
# 26                 500.0                      60000.0                 0
# 27                 500.0                      60000.0                 0
# 28                 500.0                      60000.0                 0
# 29                 500.0                      60000.0                 0
# 30                 500.0                      60000.0                 0
# 31                 500.0                      60000.0                 0
# 32                 500.0                      60000.0                 0
# 33                 500.0                      60000.0                 0
# 34                 500.0                      60000.0                 0
# 35                 500.0                      60000.0                 0
# 36                 500.0                      60000.0                 0
# 37                 500.0                      60000.0                 0
# 38                 500.0                      60000.0                 0
# 39                 500.0                      60000.0                 0
# 40                 500.0                      60000.0                 0
# 41                 500.0                      60000.0                 0
# 42                 500.0                      60000.0                 0
# 43                 500.0                      60000.0                 0
# 44                 500.0                      60000.0                 0
# 45                 500.0                      60000.0                 0
# 46                 500.0                      60000.0                 0
# 47                 500.0                      60000.0                 0
# 48                 500.0                      60000.0                 0
# 49                 500.0                      60000.0                 0
# 50                 500.0                      60000.0                 0
# 51                 500.0                      60000.0                 0
# 52                 500.0                      60000.0                 0
# 53                 500.0                      60000.0                 0
# 54                 500.0                      60000.0                 0
# 55                 500.0                      60000.0                 0
# 56                 500.0                      60000.0                 0
# 57                 500.0                      60000.0                 0
# 58                 500.0                      60000.0                 0
# 59                 500.0                      60000.0                 0
#
#                                             code_path  conc_0  \
# 0   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 1   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 2   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 3   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 4   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 5   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 6   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 7   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 8   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 9   /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 10  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 11  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 12  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 13  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 14  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 15  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 16  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 17  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 18  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 19  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 20  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 21  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 22  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 23  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 24  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 25  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 26  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 27  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 28  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 29  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 30  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 31  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 32  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 33  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 34  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 35  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 36  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 37  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 38  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 39  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 40  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 41  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 42  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 43  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 44  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 45  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 46  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 47  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 48  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 49  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 50  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 51  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 52  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 53  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 54  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 55  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 56  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 57  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 58  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
# 59  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...   400.0
#
#     critical_free_active_conc  critical_free_conc  ...  \
# 0                       150.0                20.0  ...
# 1                       150.0                20.0  ...
# 2                       150.0                20.0  ...
# 3                       150.0                20.0  ...
# 4                       150.0                20.0  ...
# 5                       150.0                20.0  ...
# 6                       150.0                20.0  ...
# 7                       150.0                20.0  ...
# 8                       150.0                20.0  ...
# 9                       150.0                20.0  ...
# 10                      150.0                20.0  ...
# 11                      150.0                20.0  ...
# 12                      150.0                20.0  ...
# 13                      150.0                20.0  ...
# 14                      150.0                20.0  ...
# 15                      150.0                20.0  ...
# 16                      150.0                20.0  ...
# 17                      150.0                20.0  ...
# 18                      150.0                20.0  ...
# 19                      150.0                20.0  ...
# 20                      150.0                20.0  ...
# 21                      150.0                20.0  ...
# 22                      150.0                20.0  ...
# 23                      150.0                20.0  ...
# 24                      150.0                20.0  ...
# 25                      150.0                20.0  ...
# 26                      150.0                20.0  ...
# 27                      150.0                20.0  ...
# 28                      150.0                20.0  ...
# 29                      150.0                20.0  ...
# 30                      150.0                20.0  ...
# 31                      150.0                20.0  ...
# 32                      150.0                20.0  ...
# 33                      150.0                20.0  ...
# 34                      150.0                20.0  ...
# 35                      150.0                20.0  ...
# 36                      150.0                20.0  ...
# 37                      150.0                20.0  ...
# 38                      150.0                20.0  ...
# 39                      150.0                20.0  ...
# 40                      150.0                20.0  ...
# 41                      150.0                20.0  ...
# 42                      150.0                20.0  ...
# 43                      150.0                20.0  ...
# 44                      150.0                20.0  ...
# 45                      150.0                20.0  ...
# 46                      150.0                20.0  ...
# 47                      150.0                20.0  ...
# 48                      150.0                20.0  ...
# 49                      150.0                20.0  ...
# 50                      150.0                20.0  ...
# 51                      150.0                20.0  ...
# 52                      150.0                20.0  ...
# 53                      150.0                20.0  ...
# 54                      150.0                20.0  ...
# 55                      150.0                20.0  ...
# 56                      150.0                20.0  ...
# 57                      150.0                20.0  ...
# 58                      150.0                20.0  ...
# 59                      150.0                20.0  ...
#
#       version_of_titration  average_init_conc  average_init_conc_normalized  \
# 0   regulator_is_initiator         365.393637                      1.826968
# 1   regulator_is_initiator         273.113174                      1.365566
# 2   regulator_is_initiator         316.632547                      1.583163
# 3   regulator_is_initiator         310.753160                      1.553766
# 4   regulator_is_initiator         271.187519                      1.355938
# 5   regulator_is_initiator         332.228162                      1.661141
# 6   regulator_is_initiator         275.172094                      1.375860
# 7   regulator_is_initiator         280.655076                      1.403275
# 8   regulator_is_initiator         301.679445                      1.508397
# 9   regulator_is_initiator         297.798367                      1.488992
# 10  regulator_is_initiator         277.576078                      1.387880
# 11  regulator_is_initiator         294.176442                      1.470882
# 12  regulator_is_initiator         284.013359                      1.420067
# 22           326.146275            326.146275                        1.630731
# 23           321.515477            321.515477                        1.607577
# 24           279.143858            279.143858                        1.395719
# 25           341.816539            341.816539                        1.709083
# 26           283.536640            283.536640                        1.417683
# 27           287.593924            287.593924                        1.437970
# 28           312.872906            312.872906                        1.564365
# 29           308.635998            308.635998                        1.543180
# 30           285.426728            285.426728                        1.427134
# 31           304.396395            304.396395                        1.521982
# 32           291.754599            291.754599                        1.458773
# 33           333.208313            333.208313                        1.666042
# 34           276.692141            276.692141                        1.383461
# 35           317.089321            317.089321                        1.585447
# 36           295.942169            295.942169                        1.479711
# 37           351.411088            351.411088                        1.757055
# 38           362.375839            362.375839                        1.811879
# 39           300.165174            300.165174                        1.500826
# 40           370.080214            370.080214                        1.850401
# 41           273.860445            273.860445                        1.369302
# 42           319.635340            319.635340                        1.598177
# 43           314.788553            314.788553                        1.573943
# 44           271.682401            271.682401                        1.358412
# 45           335.740131            335.740131                        1.678701
# 46           275.827349            275.827349                        1.379137
# 47           279.505749            279.505749                        1.397529
# 48           305.344506            305.344506                        1.526723
# 49           300.833188            300.833188                        1.504166
# 50           277.505345            277.505345                        1.387527
# 51           296.493040            296.493040                        1.482465
# 52           283.649794            283.649794                        1.418249
# 53           326.908222            326.908222                        1.634541
# 54           269.270796            269.270796                        1.346354
# 55           310.019664            310.019664                        1.550098
# 56           287.883847            287.883847                        1.439419
# 57           345.585688            345.585688                        1.727928
# 58           356.832691            356.832691                        1.784163
# 59           292.169813            292.169813                        1.460849
#
# [60 rows x 120 columns]

# %% [markdown]
# # Calculate initiation volume theoretically

# %%
def calculate_v_initi_no_overlap_switch_time_varying(df):
    try:
#         print(df.production_rate_dars1)
        production_rate_dars1 = df.production_rate_dars1
    except:
        production_rate_dars1 = 0
    return df.destruction_rate_datA / df.production_rate_lipids * df.frac_init * \
           (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
           ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))-((production_rate_dars1+ df.production_rate_dars2)/df.production_rate_lipids)

def calculate_v_initi_overlap_switch_time_varying(df):
    try:
#         print(df.production_rate_dars1)
        production_rate_dars1 = df.production_rate_dars1
    except:
        production_rate_dars1 = 0
    return (df.destruction_rate_datA + df.high_rate_datA + df.destruction_rate_rida) / df.production_rate_lipids * df.frac_init * \
           (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
           ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))- \
           ((production_rate_dars1 + df.production_rate_dars2 + df.high_rate_dars2)/df.production_rate_lipids)

data_frame["v_init_per_n_ori_th_no_time_varying"] = data_frame.apply(lambda row: calculate_v_initi_no_overlap_switch_time_varying(row), axis=1)
data_frame["v_init_per_n_ori_th_o_time_varying"] = data_frame.apply(lambda row: calculate_v_initi_no_overlap_switch_time_varying(row), axis=1)

# %%
def calculate_v_init_switch_synthesis(df):
    if df.include_synthesis==0:
        return df.destruction_rate_datA / df.production_rate_lipids * df.frac_init * \
               (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
               ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))
    else:
        return (df.destruction_rate_datA/df.total_conc) * \
                df.frac_init / (df.michaelis_const_destr/df.total_conc+ df.frac_init) * \
                (df.michaelis_const_prod / df.total_conc + 1 - df.frac_init) / \
                ((1- df.frac_init) * \
                (df.production_rate_lipids/df.total_conc + df.rate_growth * (df.michaelis_const_prod / df.total_conc + 1 - df.frac_init)))
    
data_frame["v_init_per_n_ori_synthesis"] = data_frame.apply(lambda row: calculate_v_init_switch_synthesis(row), axis=1)

# %% [markdown]
# # Calculate CV

# %%
for simu_name in data_frame.simu_name.unique():
    simu_df = data_frame[data_frame["simu_name"] == simu_name]
    data_frame.loc[data_frame['simu_name'] == simu_name, 'mean_v_init_per_n_ori'] = np.mean(simu_df["v_init_per_n_ori"])
    data_frame.loc[data_frame['simu_name'] == simu_name, 'stdd_v_init_per_n_ori'] = np.std(simu_df["v_init_per_n_ori"])
    data_frame.loc[data_frame['simu_name'] == simu_name, 'cv_v_init_per_n_ori'] = np.std(simu_df["v_init_per_n_ori"])/np.mean(simu_df["v_init_per_n_ori"])

# %% [markdown]
# # Make Legends

# %%
def make_production_rate_datA_lipids_cv_legend(destruction_rate_datA, production_rate_lipids, cv):
    return r'$\beta_{{\rm datA}}={}$ /h, $\alpha_{{\rm lipids}}={}$ /h, CV= {}'.format(np.round(destruction_rate_datA,3), 
                                                                                       np.round(production_rate_lipids,3), 
                                                                                       np.round(cv,3))

def make_production_rate_datA_cv_legend(destruction_rate_datA, cv):
    return r'$\beta_{{\rm datA}}={}$ /h, CV= {}'.format(np.round(destruction_rate_datA,3),
                                                        np.round(cv,3))

def make_production_rate_datA_legend(destruction_rate_datA):
    return r'$\beta_{{\rm datA}}={}$ min$^{{-1}}$'.format(int(destruction_rate_datA/60))

def make_production_rate_datA_lipids_legend(destruction_rate_datA, production_rate_lipids):
    return r'$\beta_{{\rm datA}}={}$ /h, \linebreak  $\alpha_{{\rm lipids}}={}$ /h'.format(np.round(destruction_rate_datA,3), 
                                                                                       np.round(production_rate_lipids,3))

def make_theoretical_v_init_legend(v_init_per_n_ori_th_no_time_varying):
    return r'$v^\ast_{{\rm th}}={} \, \mu $m$^3$'.format(np.round(v_init_per_n_ori_th_no_time_varying,3))


data_frame.loc[:, 'legend_datA_lipids_cv'] = data_frame.apply(lambda row: make_production_rate_datA_lipids_cv_legend(row.destruction_rate_datA,
                                                                                                              row.production_rate_lipids,
                                                                                                              row.cv_v_init_per_n_ori), axis = 1)

data_frame.loc[:, 'legend_datA_cv'] = data_frame.apply(lambda row: make_production_rate_datA_cv_legend(row.destruction_rate_datA,
                                                                                                              row.cv_v_init_per_n_ori), axis = 1)

data_frame.loc[:, 'legend_datA'] = data_frame.apply(lambda row: make_production_rate_datA_legend(row.destruction_rate_datA), axis = 1)

data_frame.loc[:, 'legend_datA_lipids'] = data_frame.apply(lambda row: make_production_rate_datA_lipids_legend(row.destruction_rate_datA,
                                                                                                              row.production_rate_lipids), axis = 1)

data_frame.loc[:, 'legend_v_init_th'] = data_frame.apply(lambda row: make_theoretical_v_init_legend(row.v_init_per_n_ori_th_no_time_varying), axis = 1)

# %% [markdown]
# # Determine minimal activator fraction

# %%
def determine_min_frac(filepath_h5, total_conc):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_conc'] / total_conc
    return np.min(fractions[int(fractions.size/2):])

def determine_max_frac(filepath_h5, total_conc):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_conc'] / total_conc
    return np.max(fractions[int(fractions.size/2):])

data_frame.loc[:, 'min_frac'] = data_frame.apply(lambda row: determine_min_frac(row.path_dataset, row.total_conc), axis = 1)
data_frame.loc[:, 'max_frac'] = data_frame.apply(lambda row: determine_max_frac(row.path_dataset, row.total_conc), axis = 1)
data_frame['amplitude_frac'] = data_frame['max_frac']-data_frame['min_frac']
data_frame['relative_change_frac']= data_frame['min_frac']/data_frame['max_frac']

# %% [markdown]
# # Plot initiation volume per origin

# %%
sns.set(style="ticks")
sns.set_context("poster")

fig, ax = plt.subplots(figsize=(7,7))
sns.lineplot(
    x='rate_growth', 
    y='v_init_per_n_ori',
    data=data_frame.sort_values(by=["destruction_rate_datA"], ascending=False),
    hue='legend_datA',
    palette= [green, blue, pinkish_red], # yellow],
    linewidth = 3.5,
    ax=ax
);
ax.lines[0].set_linestyle("--")
ax.lines[1].set_linestyle("--")
ax.lines[2].set_linestyle("--")
ax.lines[3].set_linestyle("--")
ax.margins(0)

# Theoretical prediction
ax.hlines(data_frame['v_init_per_n_ori_th_no_time_varying'][0], 
            data_frame['rate_growth'].min(), 
            data_frame['rate_growth'].max(), 
            color='black', 
            linestyle='-',
            label= data_frame['legend_v_init_th'].iloc[0])
# Experimental results
# ax.hlines(v_init_exp, 
#             data_frame['rate_growth'].min(), 
#             data_frame['rate_growth'].max(), 
#             color='black', 
#             label= r'$v^\ast_{{\rm exp}}={} \, \mu m^3$'.format(v_init_exp))
# upper_bound = np.array(data_frame['v_init_per_n_ori_th_no_time_varying']) + std_exp
# lower_bound = np.array(data_frame['v_init_per_n_ori_th_no_time_varying']) - std_exp
# ax.axhspan(upper_bound[0], lower_bound[0], facecolor='black', alpha=0.1)

ax.set(xlabel=r'$\lambda$ [h$^{-1}$]', ylabel=r'$v^\ast$ [$\mu$m$^3$]')
ax.set(ylim=(0,0.45))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
plt.savefig(file_path + '/Fig_S5_v_init.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# # Plot amplitude time varying

# %%
sns.set(style="ticks")
sns.set_context("poster")

fig, ax = plt.subplots(figsize=(7,7))
sns.lineplot(
    x='rate_growth', 
    y='amplitude_frac',
    data=data_frame.sort_values(by=["destruction_rate_datA"], ascending=False),
    hue='legend_datA',
    dashes=[(4, 1), (4, 1), (4, 1), (4, 1)],
    markers=True,
    palette= [green, blue,  pinkish_red], # yellow],
    linewidth = 3.5,
    ax=ax
);
ax.lines[0].set_linestyle("--")
ax.lines[1].set_linestyle("--")
ax.lines[2].set_linestyle("--")
ax.lines[3].set_linestyle("--")
ax.margins(0)
ax.set(xlabel=r'$\lambda$ [h$^{-1}$]', ylabel=r'$\Delta f = f^\ast-f_{\rm min}$')
# plt.legend(labels=legend
ax.set(ylim=(0,0.75))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
plt.savefig(file_path + '/S7_ultra_sensitivity.pdf', format='pdf', bbox_inches='tight')
