# %%
import numpy as np
import pandas as pd
import os
from glob import glob
from pprint import pprint
import json
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.pyplot as plt

import cellcycle.PlottingTools as plottingTools
from cellcycle.ParameterSet import ParameterSet
import cellcycle.DataStorage as dataStorage
import cellcycle.DataAnalysis as dataAnalysis
import cellcycle.MakeDataframe as makeDataframe

# %%
file_path = '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/results/paper/SI/S5_LD_ultra_sensitive'
parameter_path = os.path.join(file_path, 'parameter_set.csv')

# %%
pinkish_red = (247 / 255, 109 / 255, 109 / 255)
green = (0 / 255, 133 / 255, 86 / 255)
dark_blue = (36 / 255, 49 / 255, 94 / 255)
light_blue = (168 / 255, 209 / 255, 231 / 255)
blue = (55 / 255, 71 / 255, 133 / 255)
yellow = (247 / 255, 233 / 255, 160 / 255)

# %%
v_init_exp = 0.28
std_exp = 0.05

# %%
data_frame = makeDataframe.make_dataframe(file_path)
data_frame = makeDataframe.add_average_values_to_df(data_frame)
data_frame = makeDataframe.add_theoretical_init_reg_concentrations_to_df(data_frame)
data_frame
# Out:
# ['/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/results/paper/SI/S5_LD_ultra_sensitive/LD_ultra_sens_10',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/results/paper/SI/S5_LD_ultra_sensitive/LD_ultra_sens_100',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/results/paper/SI/S5_LD_ultra_sensitive/rate_comparison.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/results/paper/SI/S5_LD_ultra_sensitive/Fig_S5_v_init.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/results/paper/SI/S5_LD_ultra_sensitive/LD_ultra_sens_20',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/results/paper/SI/S5_LD_ultra_sensitive/Fig_S5_fraction.pdf']
#             simu_name                                          simu_path  \
# 0    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 1    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 2    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 3    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 4    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 5    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 6    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 7    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 8    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 9    LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 10   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 11   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 12   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 13   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 14   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 15   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 16   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 17   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 18   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 19   LD_ultra_sens_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 20  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 21  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 22  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 23  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 24  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 25  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 26  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 27  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 28  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 29  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 30  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 31  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 32  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 33  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 34  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 35  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 36  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 37  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 38  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 39  LD_ultra_sens_100  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 40   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 41   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 42   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 43   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 44   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 45   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 46   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 47   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 48   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 49   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 50   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 51   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 52   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 53   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 54   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 55   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 56   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 57   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 58   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 59   LD_ultra_sens_20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
#
#           sub_simu_name                                      sub_simu_path  \
# 0    vary_growth_rate_0  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 1   vary_growth_rate_17  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 2    vary_growth_rate_5  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 3    vary_growth_rate_6  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 4   vary_growth_rate_18  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 5    vary_growth_rate_3  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 6   vary_growth_rate_16  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 7   vary_growth_rate_14  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 8    vary_growth_rate_8  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 9    vary_growth_rate_9  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 10  vary_growth_rate_15  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 11  vary_growth_rate_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 12  vary_growth_rate_13  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 13   vary_growth_rate_4  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 14  vary_growth_rate_19  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 15   vary_growth_rate_7  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 16  vary_growth_rate_12  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 17   vary_growth_rate_2  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 18   vary_growth_rate_1  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 19  vary_growth_rate_11  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 20   vary_growth_rate_0  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 21  vary_growth_rate_17  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 22   vary_growth_rate_5  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 23   vary_growth_rate_6  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 24  vary_growth_rate_18  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 25   vary_growth_rate_3  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 26  vary_growth_rate_16  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 27  vary_growth_rate_14  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 28   vary_growth_rate_8  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 29   vary_growth_rate_9  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 30  vary_growth_rate_15  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 31  vary_growth_rate_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 32  vary_growth_rate_13  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 33   vary_growth_rate_4  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 34  vary_growth_rate_19  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 35   vary_growth_rate_7  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 36  vary_growth_rate_12  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 37   vary_growth_rate_2  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 38   vary_growth_rate_1  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 39  vary_growth_rate_11  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 40   vary_growth_rate_0  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 41  vary_growth_rate_17  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 42   vary_growth_rate_5  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 43   vary_growth_rate_6  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 44  vary_growth_rate_18  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 45   vary_growth_rate_3  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 46  vary_growth_rate_16  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 47  vary_growth_rate_14  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 48   vary_growth_rate_8  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 49   vary_growth_rate_9  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 50  vary_growth_rate_15  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 51  vary_growth_rate_10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 52  vary_growth_rate_13  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 53   vary_growth_rate_4  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 54  vary_growth_rate_19  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 55   vary_growth_rate_7  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 56  vary_growth_rate_12  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 57   vary_growth_rate_2  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 58   vary_growth_rate_1  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 59  vary_growth_rate_11  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
#
#                                   path_parameter_file  \
# 0   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 1   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 2   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 3   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 4   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 5   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 6   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 7   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 8   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 9   /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 11  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 12  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 13  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 14  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 15  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 16  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 17  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 18  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 19  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 21  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 22  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 23  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 24  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 25  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 26  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 27  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 28  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 29  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 30  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 31  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 32  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 33  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 34  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 35  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 36  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 37  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 38  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 39  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 40  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 41  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 42  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 43  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 44  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 45  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 46  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 47  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 48  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 49  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 50  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 51  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 52  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 53  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 54  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 55  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 56  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 57  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 58  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
# 59  /home/berger/Documents/Arbeit/PhD/data/Ultrase...
#
#                                          path_dataset  n_series  id  \
# 0   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   0
# 1   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  17
# 2   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   5
# 3   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   6
# 4   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  18
# 5   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   3
# 6   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  16
# 7   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  14
# 8   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   8
# 9   /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   9
# 10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  15
# 11  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  10
# 12  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  13
# 13  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   4
# 14  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  19
# 15  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   7
# 16  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  12
# 17  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   2
# 18  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   1
# 19  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  11
# 20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   0
# 21  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  17
# 22  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   5
# 23  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   6
# 24  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  18
# 25  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   3
# 26  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  16
# 27  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  14
# 28  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   8
# 29  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   9
# 30  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  15
# 31  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  10
# 32  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  13
# 33  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   4
# 34  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  19
# 35  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   7
# 36  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  12
# 37  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   2
# 38  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   1
# 39  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  11
# 40  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   0
# 41  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  17
# 42  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   5
# 43  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   6
# 44  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  18
# 45  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   3
# 46  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  16
# 47  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  14
# 48  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   8
# 49  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   9
# 50  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  15
# 51  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  10
# 52  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  13
# 53  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   4
# 54  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  19
# 55  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   7
# 56  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  12
# 57  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   2
# 58  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20   1
# 59  /home/berger/Documents/Arbeit/PhD/data/Ultrase...        20  11
#
#                                             root_path         file_name  ...  \
# 0   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 1   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 2   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 3   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 4   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 5   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 6   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 7   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 8   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 9   /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 10  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 11  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 12  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 13  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 14  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 15  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 16  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 17  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 18  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 19  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 20  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 21  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 22  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 23  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 24  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 25  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 26  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 27  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 28  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 29  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 30  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 31  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 32  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 33  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 34  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 35  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 36  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 37  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 38  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 39  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 40  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 41  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 42  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 43  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 44  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 45  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 46  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 47  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 48  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 49  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 50  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 51  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 52  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 53  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 54  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 55  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 56  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 57  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 58  /home/berger/Documents/Arbeit/PhD/data/Ultrase...  vary_growth_rate  ...
# 24           279.143858            279.143858                         1.395719
# 25           341.816539            341.816539                         1.709083
# 26           283.536640            283.536640                         1.417683
# 27           287.593924            287.593924                         1.437970
# 28           312.872906            312.872906                         1.564365
# 29           308.635998            308.635998                         1.543180
# 30           285.426728            285.426728                         1.427134
# 31           304.396395            304.396395                         1.521982
# 32           291.754599            291.754599                         1.458773
# 33           333.208313            333.208313                         1.666042
# 34           276.692141            276.692141                         1.383461
# 35           317.089321            317.089321                         1.585447
# 36           295.942169            295.942169                         1.479711
# 37           351.411088            351.411088                         1.757055
# 38           362.375839            362.375839                         1.811879
# 39           300.165174            300.165174                         1.500826
# 40           370.080214            370.080214                         1.850401
# 41           273.860445            273.860445                         1.369302
# 42           319.635340            319.635340                         1.598177
# 43           314.788553            314.788553                         1.573943
# 44           271.682401            271.682401                         1.358412
# 45           335.740131            335.740131                         1.678701
# 46           275.827349            275.827349                         1.379137
# 47           279.505749            279.505749                         1.397529
# 48           305.344506            305.344506                         1.526723
# 49           300.833188            300.833188                         1.504166
# 50           277.505345            277.505345                         1.387527
# 51           296.493040            296.493040                         1.482465
# 52           283.649794            283.649794                         1.418249
# 53           326.908222            326.908222                         1.634541
# 54           269.270796            269.270796                         1.346354
# 55           310.019664            310.019664                         1.550098
# 56           287.883847            287.883847                         1.439419
# 57           345.585688            345.585688                         1.727928
# 58           356.832691            356.832691                         1.784163
# 59           292.169813            292.169813                         1.460849
#
# [60 rows x 120 columns]

# %% [markdown]
# # Calculate initiation volume theoretically

# %%
def calculate_v_initi_no_overlap_switch_time_varying(df):
    try:
#         print(df.production_rate_dars1)
        production_rate_dars1 = df.production_rate_dars1
    except:
        production_rate_dars1 = 0
    return df.destruction_rate_datA / df.production_rate_lipids * df.frac_init * \
           (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
           ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))-((production_rate_dars1+ df.production_rate_dars2)/df.production_rate_lipids)

def calculate_v_initi_overlap_switch_time_varying(df):
    try:
#         print(df.production_rate_dars1)
        production_rate_dars1 = df.production_rate_dars1
    except:
        production_rate_dars1 = 0
    return (df.destruction_rate_datA + df.high_rate_datA + df.destruction_rate_rida) / df.production_rate_lipids * df.frac_init * \
           (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
           ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))- \
           ((production_rate_dars1 + df.production_rate_dars2 + df.high_rate_dars2)/df.production_rate_lipids)

data_frame["v_init_per_n_ori_th_no_time_varying"] = data_frame.apply(lambda row: calculate_v_initi_no_overlap_switch_time_varying(row), axis=1)
data_frame["v_init_per_n_ori_th_o_time_varying"] = data_frame.apply(lambda row: calculate_v_initi_no_overlap_switch_time_varying(row), axis=1)

# %%
def calculate_v_init_switch_synthesis(df):
    if df.include_synthesis==0:
        return df.destruction_rate_datA / df.production_rate_lipids * df.frac_init * \
               (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
               ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))
    else:
        return (df.destruction_rate_datA/df.total_conc) * \
                df.frac_init / (df.michaelis_const_destr/df.total_conc+ df.frac_init) * \
                (df.michaelis_const_prod / df.total_conc + 1 - df.frac_init) / \
                ((1- df.frac_init) * \
                (df.production_rate_lipids/df.total_conc + df.rate_growth * (df.michaelis_const_prod / df.total_conc + 1 - df.frac_init)))
    
data_frame["v_init_per_n_ori_synthesis"] = data_frame.apply(lambda row: calculate_v_init_switch_synthesis(row), axis=1)

# %% [markdown]
# # Calculate CV

# %%
for simu_name in data_frame.simu_name.unique():
    simu_df = data_frame[data_frame["simu_name"] == simu_name]
    data_frame.loc[data_frame['simu_name'] == simu_name, 'mean_v_init_per_n_ori'] = np.mean(simu_df["v_init_per_n_ori"])
    data_frame.loc[data_frame['simu_name'] == simu_name, 'stdd_v_init_per_n_ori'] = np.std(simu_df["v_init_per_n_ori"])
    data_frame.loc[data_frame['simu_name'] == simu_name, 'cv_v_init_per_n_ori'] = np.std(simu_df["v_init_per_n_ori"])/np.mean(simu_df["v_init_per_n_ori"])

# %% [markdown]
# # Make Legends

# %%
def make_production_rate_datA_lipids_cv_legend(destruction_rate_datA, production_rate_lipids, cv):
    return r'$\beta_{{\rm datA}}={}$ /h, $\alpha_{{\rm lipids}}={}$ /h, CV= {}'.format(np.round(destruction_rate_datA,3), 
                                                                                       np.round(production_rate_lipids,3), 
                                                                                       np.round(cv,3))

def make_production_rate_datA_cv_legend(destruction_rate_datA, cv):
    return r'$\beta_{{\rm datA}}={}$ /h, CV= {}'.format(np.round(destruction_rate_datA,3),
                                                        np.round(cv,3))

def make_production_rate_datA_legend(destruction_rate_datA):
    return r'$\beta_{{\rm datA}}={}$ min$^{{-1}}$'.format(int(destruction_rate_datA/60))

def make_production_rate_datA_lipids_legend(destruction_rate_datA, production_rate_lipids):
    return r'$\beta_{{\rm datA}}={}$ /h, \linebreak  $\alpha_{{\rm lipids}}={}$ /h'.format(np.round(destruction_rate_datA,3), 
                                                                                       np.round(production_rate_lipids,3))

def make_theoretical_v_init_legend(v_init_per_n_ori_th_no_time_varying):
    return r'$v^\ast_{{\rm th}}={} \, \mu $m$^3$'.format(np.round(v_init_per_n_ori_th_no_time_varying,3))


data_frame.loc[:, 'legend_datA_lipids_cv'] = data_frame.apply(lambda row: make_production_rate_datA_lipids_cv_legend(row.destruction_rate_datA,
                                                                                                              row.production_rate_lipids,
                                                                                                              row.cv_v_init_per_n_ori), axis = 1)

data_frame.loc[:, 'legend_datA_cv'] = data_frame.apply(lambda row: make_production_rate_datA_cv_legend(row.destruction_rate_datA,
                                                                                                              row.cv_v_init_per_n_ori), axis = 1)

data_frame.loc[:, 'legend_datA'] = data_frame.apply(lambda row: make_production_rate_datA_legend(row.destruction_rate_datA), axis = 1)

data_frame.loc[:, 'legend_datA_lipids'] = data_frame.apply(lambda row: make_production_rate_datA_lipids_legend(row.destruction_rate_datA,
                                                                                                              row.production_rate_lipids), axis = 1)

data_frame.loc[:, 'legend_v_init_th'] = data_frame.apply(lambda row: make_theoretical_v_init_legend(row.v_init_per_n_ori_th_no_time_varying), axis = 1)

# %% [markdown]
# # Determine minimal activator fraction

# %%
def determine_min_frac(filepath_h5, total_conc):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_conc'] / total_conc
    return np.min(fractions[int(fractions.size/2):])

def determine_max_frac(filepath_h5, total_conc):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_conc'] / total_conc
    return np.max(fractions[int(fractions.size/2):])

data_frame.loc[:, 'min_frac'] = data_frame.apply(lambda row: determine_min_frac(row.path_dataset, row.total_conc), axis = 1)
data_frame.loc[:, 'max_frac'] = data_frame.apply(lambda row: determine_max_frac(row.path_dataset, row.total_conc), axis = 1)
data_frame['amplitude_frac'] = data_frame['max_frac']-data_frame['min_frac']
data_frame['relative_change_frac']= data_frame['min_frac']/data_frame['max_frac']

# %% [markdown]
# # Plot initiation volume per origin

# %%
sns.set(style="ticks")
sns.set_context("poster")

fig, ax = plt.subplots(figsize=(7,7))
sns.lineplot(
    x='rate_growth', 
    y='v_init_per_n_ori',
    data=data_frame.sort_values(by=["destruction_rate_datA"], ascending=False),
    hue='legend_datA',
    palette= [green, blue, pinkish_red], # yellow],
    linewidth = 3.5,
    ax=ax
);
ax.lines[0].set_linestyle("--")
ax.lines[1].set_linestyle("--")
ax.lines[2].set_linestyle("--")
ax.lines[3].set_linestyle("--")
ax.margins(0)

# Theoretical prediction
ax.hlines(data_frame['v_init_per_n_ori_th_no_time_varying'][0], 
            data_frame['rate_growth'].min(), 
            data_frame['rate_growth'].max(), 
            color='black', 
            linestyle='-',
            label= data_frame['legend_v_init_th'].iloc[0])
# Experimental results
# ax.hlines(v_init_exp, 
#             data_frame['rate_growth'].min(), 
#             data_frame['rate_growth'].max(), 
#             color='black', 
#             label= r'$v^\ast_{{\rm exp}}={} \, \mu m^3$'.format(v_init_exp))
# upper_bound = np.array(data_frame['v_init_per_n_ori_th_no_time_varying']) + std_exp
# lower_bound = np.array(data_frame['v_init_per_n_ori_th_no_time_varying']) - std_exp
# ax.axhspan(upper_bound[0], lower_bound[0], facecolor='black', alpha=0.1)

ax.set(xlabel=r'$\lambda$ [h$^{-1}$]', ylabel=r'$v^\ast$ [$\mu$m$^3$]')
ax.set(ylim=(0,0.45))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
plt.savefig(file_path + '/Fig_S5_v_init.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# # Plot amplitude time varying

# %%
sns.set(style="ticks")
sns.set_context("poster")

fig, ax = plt.subplots(figsize=(7,7))
sns.lineplot(
    x='rate_growth', 
    y='amplitude_frac',
    data=data_frame.sort_values(by=["destruction_rate_datA"], ascending=False),
    hue='legend_datA',
    dashes=[(4, 1), (4, 1), (4, 1), (4, 1)],
    markers=True,
    palette= [green, blue,  pinkish_red], # yellow],
    linewidth = 3.5,
    ax=ax
);
ax.lines[0].set_linestyle("--")
ax.lines[1].set_linestyle("--")
ax.lines[2].set_linestyle("--")
ax.lines[3].set_linestyle("--")
ax.margins(0)
ax.set(xlabel=r'$\lambda$ [h$^{-1}$]', ylabel=r'$\Delta f = f^\ast-f_{\rm min}$')
# plt.legend(labels=legend
ax.set(ylim=(0,0.75))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
plt.savefig(file_path + '/Fig_S5_fraction.pdf', format='pdf', bbox_inches='tight')
