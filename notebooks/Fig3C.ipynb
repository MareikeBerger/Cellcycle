# %%
import numpy as np
import pandas as pd
import os
from glob import glob
from pprint import pprint
import json
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.colors import ListedColormap, BoundaryNorm
import matplotlib.pyplot as plt

import cellcycle.PlottingTools as plottingTools
from cellcycle.ParameterSet import ParameterSet
import cellcycle.DataStorage as dataStorage
import cellcycle.DataAnalysis as dataAnalysis
import cellcycle.MakeDataframe as makeDataframe
from cellcycle import mainClass

# %% [markdown]
# The following lines need to be used if data the from downloaded dataset should be used. The location of the ``Data`` folder needs to be specified by the parameter ``DATA_FOLDER_PATH`` in the file ``input_params.json``.
#
# If you want to analyse your own dataset you need to set the variable ``file_path`` to the folder where the simulation is located. Importantly, in this folder there should only be located exactly one simulation.

# %%
file_path_input_params_json = '../input_params.json'
input_param_dict = mainClass.extract_variables_from_input_params_json(file_path_input_params_json)
root_path = input_param_dict["DATA_FOLDER_PATH"]
simulation_location = 'fig_3/Fig_3C'
file_path = os.path.join(root_path, simulation_location)
print('file_path', file_path)
parameter_path = os.path.join(file_path, 'parameter_set.csv')
print('parameter_path', parameter_path)
# Out:
# file_path /home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C
# parameter_path /home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/parameter_set.csv

# %%
pinkish_red = (247 / 255, 109 / 255, 109 / 255)
green = (0 / 255, 133 / 255, 86 / 255)
dark_blue = (36 / 255, 49 / 255, 94 / 255)
light_blue = (168 / 255, 209 / 255, 231 / 255)
blue = (55 / 255, 71 / 255, 133 / 255)
yellow = (247 / 255, 233 / 255, 160 / 255)

# %%
v_init_exp = 0.28
std_exp = 0.05

# %%
data_frame = makeDataframe.make_dataframe(file_path)
data_frame = makeDataframe.add_average_values_to_df(data_frame)
data_frame = makeDataframe.add_theoretical_init_reg_concentrations_to_df(data_frame)
data_frame
# Out:
# ['/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/LD_100',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/LD_10',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/Fig_3D_rida_400.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/Fig_3D_rida_1500.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/Fig_3D.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/Fig_3C_poster.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/Fig_3D_rida_500.pdf',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/LD_20',
#  '/home/berger/Documents/Arbeit/PhD/data/UltrasensitivityCombined/NatCom/fig_3/Fig_3C/LDDR_amplitude_rida_500']
#     amplitude_oscillations  aspect_ratio  basal_rate_initiator  \
# 0                      NaN           4.0            500.000000
# 1                      NaN           4.0            500.000000
# 2                      NaN           4.0            500.000000
# 3                      NaN           4.0            500.000000
# 4                      NaN           4.0            500.000000
# 5                      NaN           4.0            500.000000
# 6                      NaN           4.0            500.000000
# 7                      NaN           4.0            500.000000
# 8                      NaN           4.0            500.000000
# 9                      NaN           4.0            500.000000
# 10                     NaN           4.0            500.000000
# 11                     NaN           4.0            500.000000
# 12                     NaN           4.0            500.000000
# 13                     NaN           4.0            500.000000
# 14                     NaN           4.0            500.000000
# 15                     NaN           4.0            500.000000
# 16                     NaN           4.0            500.000000
# 17                     NaN           4.0            500.000000
# 18                     NaN           4.0            500.000000
# 19                     NaN           4.0            500.000000
# 20                     NaN           4.0            500.000000
# 21                     NaN           4.0            500.000000
# 22                     NaN           4.0            500.000000
# 23                     NaN           4.0            500.000000
# 24                     NaN           4.0            500.000000
/home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 14  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 15  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 16  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 17  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 18  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 19  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 20  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 21  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 22  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 23  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 24  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 25  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 26  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 27  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 28  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 29  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# ..                                                ...  ...
# 50                                                NaN  ...
# 51                                                NaN  ...
# 52                                                NaN  ...
# 53                                                NaN  ...
# 54                                                NaN  ...
# 55                                                NaN  ...
# 56                                                NaN  ...
# 57                                                NaN  ...
# 58                                                NaN  ...
# 59                                                NaN  ...
# 60  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 61  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 62  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 63  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 64  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 65  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 66  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 67  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 68  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 69  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 70  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 71  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 72  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 73  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 74  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 75  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 76  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 77  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 78  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
# 79  /home/berger/Documents/Arbeit/PhD/MyCode/Mecha...  ...
#
#           version_of_titration  average_init_conc  \
# 0       regulator_is_initiator         362.452619
# 1       regulator_is_initiator         273.685014
# 2       regulator_is_initiator         317.984206
# 3       regulator_is_initiator         312.257888
# 4       regulator_is_initiator         271.615082
# 5       regulator_is_initiator         332.499682
# 6       regulator_is_initiator         275.884851
# 7       regulator_is_initiator         281.632824
# 8       regulator_is_initiator         303.204765
# 9       regulator_is_initiator         299.277264
# 10      regulator_is_initiator         278.415755
# 11      regulator_is_initiator         295.592641
# 12      regulator_is_initiator         285.120165
# 13      regulator_is_initiator         324.899676
# 14      regulator_is_initiator         269.568449
# 15      regulator_is_initiator         307.465199
# 16      regulator_is_initiator         288.586816
# 17      regulator_is_initiator         340.982863
# 18      regulator_is_initiator         350.748596
# 19      regulator_is_initiator         292.060119
# 20      regulator_is_initiator         360.294068
# 21      regulator_is_initiator         268.272214
# 22      regulator_is_initiator         313.665994
# 23      regulator_is_initiator         307.626870
# 24      regulator_is_initiator         266.239899
# 25      regulator_is_initiator         328.951705
# 26      regulator_is_initiator         270.497740
# 27      regulator_is_initiator         276.353715
# 28      regulator_is_initiator         298.283165
# 29      regulator_is_initiator         294.314980
# ..                         ...                ...
# 50  regulator_is_not_initiator         127.712262
# 51  regulator_is_not_initiator         132.132012
# 52  regulator_is_not_initiator         129.444506
# 53  regulator_is_not_initiator         138.824633
# 54  regulator_is_not_initiator         125.712264
# 55  regulator_is_not_initiator         134.835436
# 56  regulator_is_not_initiator         130.353161
# 57  regulator_is_not_initiator         142.657262
# 58  regulator_is_not_initiator         144.913716
# 59  regulator_is_not_initiator         131.248457
# 60      regulator_is_initiator         384.050654
# 61      regulator_is_initiator         411.836712
# 62      regulator_is_initiator         390.935475
# 63      regulator_is_initiator         392.707962
# 64      regulator_is_initiator         414.015305
# 65      regulator_is_initiator         388.763849
# 66      regulator_is_initiator         409.604361
# 67      regulator_is_initiator         406.444974
# 68      regulator_is_initiator         397.158577
# 69      regulator_is_initiator         399.244851
# 70      regulator_is_initiator         407.616300
# 71      regulator_is_initiator         401.107895
# 72      regulator_is_initiator         405.467780
# 73      regulator_is_initiator         389.916245
# 74      regulator_is_initiator         416.028496
# 75      regulator_is_initiator         394.917071
# 76      regulator_is_initiator         404.247378
# 77      regulator_is_initiator         387.406776
# 78      regulator_is_initiator         385.836130
# 79      regulator_is_initiator         402.785652
# 24                         1.336483
# 25                         1.640400
# 26                         1.355908
# 27                         1.374838
# 28                         1.498200
# 29                         1.477315
# ..                              ...
# 50                         1.278251
# 51                         1.322761
# 52                         1.293240
# 53                         1.386647
# 54                         1.258722
# 55                         1.351930
# 56                         1.303087
# 57                         1.426278
# 58                         1.449751
# 59                         1.313010
# 60                        20.622167
# 61                        11.807115
# 62                        20.418792
# 63                        21.072866
# 64                        11.125774
# 65                        20.402267
# 66                        12.546911
# 67                        14.886844
# 68                        21.762591
# 69                        21.644683
# 70                        13.415911
# 71                        21.626247
# 72                        17.279815
# 73                        20.307586
# 74                        10.518819
# 75                        21.535881
# 76                        19.345798
# 77                        20.479830
# 78                        20.550518
# 79                        20.737776
#
# [80 rows x 141 columns]

# %% [markdown]
# # Calculate initiation volume theoretically

# %%
def calculate_v_initi_no_overlap_switch_time_varying(df):
    try:
#         print(df.production_rate_dars1)
        production_rate_dars1 = df.production_rate_dars1
    except:
        production_rate_dars1 = 0
    return df.destruction_rate_datA / df.production_rate_lipids * df.frac_init * \
           (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
           ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))-((production_rate_dars1+ df.production_rate_dars2)/df.production_rate_lipids)

def calculate_v_initi_overlap_switch_time_varying(df):
    try:
#         print(df.production_rate_dars1)
        production_rate_dars1 = df.production_rate_dars1
    except:
        production_rate_dars1 = 0
    return (df.destruction_rate_datA + df.high_rate_datA + df.destruction_rate_rida) / df.production_rate_lipids * df.frac_init * \
           (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
           ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))- \
           ((production_rate_dars1 + df.production_rate_dars2 + df.high_rate_dars2)/df.production_rate_lipids)

data_frame["v_init_per_n_ori_th_no_time_varying"] = data_frame.apply(lambda row: calculate_v_initi_no_overlap_switch_time_varying(row), axis=1)
data_frame["v_init_per_n_ori_th_o_time_varying"] = data_frame.apply(lambda row: calculate_v_initi_no_overlap_switch_time_varying(row), axis=1)

# %%
def calculate_v_init_switch_synthesis(df):
    if df.include_synthesis==0:
        return df.destruction_rate_datA / df.production_rate_lipids * df.frac_init * \
               (df.michaelis_const_prod + (1 - df.frac_init) * df.total_conc) / \
               ((1 - df.frac_init) * (df.michaelis_const_destr + df.frac_init * df.total_conc))
    else:
        return (df.destruction_rate_datA/df.total_conc) * \
                df.frac_init / (df.michaelis_const_destr/df.total_conc+ df.frac_init) * \
                (df.michaelis_const_prod / df.total_conc + 1 - df.frac_init) / \
                ((1- df.frac_init) * \
                (df.production_rate_lipids/df.total_conc + df.rate_growth * (df.michaelis_const_prod / df.total_conc + 1 - df.frac_init)))
    
data_frame["v_init_per_n_ori_synthesis"] = data_frame.apply(lambda row: calculate_v_init_switch_synthesis(row), axis=1)

# %% [markdown]
# # Calculate CV

# %%
for simu_name in data_frame.simu_name.unique():
    simu_df = data_frame[data_frame["simu_name"] == simu_name]
    data_frame.loc[data_frame['simu_name'] == simu_name, 'mean_v_init_per_n_ori'] = np.mean(simu_df["v_init_per_n_ori"])
    data_frame.loc[data_frame['simu_name'] == simu_name, 'stdd_v_init_per_n_ori'] = np.std(simu_df["v_init_per_n_ori"])
    data_frame.loc[data_frame['simu_name'] == simu_name, 'cv_v_init_per_n_ori'] = np.std(simu_df["v_init_per_n_ori"])/np.mean(simu_df["v_init_per_n_ori"])

# %% [markdown]
# # Make Legends

# %%
def make_production_rate_datA_lipids_cv_legend(destruction_rate_datA, production_rate_lipids, cv):
    return r'$\beta_{{\rm datA}}={}$ /h, $\alpha_{{\rm lipids}}={}$ /h, CV= {}'.format(np.round(destruction_rate_datA,3), 
                                                                                       np.round(production_rate_lipids,3), 
                                                                                       np.round(cv,3))

def make_production_rate_datA_cv_legend(destruction_rate_datA, cv):
    return r'$\beta_{{\rm datA}}={}$ /h, CV= {}'.format(np.round(destruction_rate_datA,3),
                                                        np.round(cv,3))

def make_production_rate_datA_legend(destruction_rate_datA, high_rate_datA):
    return r'$\beta_{{\rm datA}}={}$ min$^{{-1}}$'.format(int((destruction_rate_datA+high_rate_datA)/60))

def make_production_rate_datA_lipids_legend(destruction_rate_datA, production_rate_lipids):
    return r'$\beta_{{\rm datA}}={}$ /h, \linebreak  $\alpha_{{\rm lipids}}={}$ /h'.format(np.round(destruction_rate_datA,3), 
                                                                                       np.round(production_rate_lipids,3))

def make_theoretical_v_init_legend(v_init_per_n_ori_th_no_time_varying):
    return r'$v^\ast_{{\rm th}}={} \, \mu $m$^3$'.format(np.round(v_init_per_n_ori_th_no_time_varying,3))


def make_paper_legend(destruction_rate_rida):
    if destruction_rate_rida == 0:
        return 'LD model'
    else:
        return 'LDDR model'
    
data_frame.loc[:, 'legend_datA_lipids_cv'] = data_frame.apply(lambda row: make_production_rate_datA_lipids_cv_legend(row.destruction_rate_datA,
                                                                                                              row.production_rate_lipids,
                                                                                                              row.cv_v_init_per_n_ori), axis = 1)

data_frame.loc[:, 'legend_datA_cv'] = data_frame.apply(lambda row: make_production_rate_datA_cv_legend(row.destruction_rate_datA,
                                                                                                              row.cv_v_init_per_n_ori), axis = 1)

data_frame.loc[:, 'legend_datA'] = data_frame.apply(lambda row: make_production_rate_datA_legend(row.destruction_rate_datA, row.high_rate_datA), axis = 1)

data_frame.loc[:, 'legend_datA_lipids'] = data_frame.apply(lambda row: make_production_rate_datA_lipids_legend(row.destruction_rate_datA,
                                                                                                              row.production_rate_lipids), axis = 1)

data_frame.loc[:, 'legend_v_init_th'] = data_frame.apply(lambda row: make_theoretical_v_init_legend(row.v_init_per_n_ori_th_no_time_varying), axis = 1)
data_frame.loc[:, 'model:'] = data_frame.apply(lambda row: make_paper_legend(row.destruction_rate_rida), axis = 1)

# %% [markdown]
# # Determine minimal activator fraction

# %%
def determine_min_frac(filepath_h5, total_conc):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_conc'] / total_conc
    return np.min(fractions[int(fractions.size/2):])

def determine_max_frac(filepath_h5, total_conc):
    data_frame_traces = pd.read_hdf(filepath_h5, key='dataset_time_traces')
    fractions = data_frame_traces['active_conc'] / total_conc
    return np.max(fractions[int(fractions.size/2):])

data_frame.loc[:, 'min_frac'] = data_frame.apply(lambda row: determine_min_frac(row.path_dataset, row.total_conc), axis = 1)
data_frame.loc[:, 'max_frac'] = data_frame.apply(lambda row: determine_max_frac(row.path_dataset, row.total_conc), axis = 1)
data_frame['amplitude_frac'] = data_frame['max_frac']-data_frame['min_frac']
data_frame['relative_change_frac']= data_frame['min_frac']/data_frame['max_frac']

# %% [markdown]
# # Plot initiation volume per origin

# %%
sns.set(style="ticks")
sns.set_context("poster")

fig, ax = plt.subplots(figsize=(7,5))
sns.lineplot(
    x='rate_growth', 
    y='v_init_per_n_ori',
    data=data_frame.sort_values(by=["destruction_rate_datA"], ascending=False),
    hue='legend_datA',
    palette= [green, blue, pinkish_red],#, yellow],
    style='lddr',
    linewidth = 3.5,
    ax=ax
);
ax.lines[0].set_linestyle("--")
ax.lines[1].set_linestyle("--")
ax.lines[2].set_linestyle("--")
ax.lines[3].set_linestyle("--")
ax.margins(0)

# Theoretical prediction
ax.hlines(data_frame['v_init_per_n_ori_th_no_time_varying'][0], 
            data_frame['rate_growth'].min(), 
            data_frame['rate_growth'].max(), 
            color='black', 
            linestyle='-',
            label= data_frame['legend_v_init_th'].iloc[0])
# Experimental results
# ax.hlines(v_init_exp, 
#             data_frame['rate_growth'].min(), 
#             data_frame['rate_growth'].max(), 
#             color='black', 
#             label= r'$v^\ast_{{\rm exp}}={} \, \mu m^3$'.format(v_init_exp))
# upper_bound = np.array(data_frame['v_init_per_n_ori_th_no_time_varying']) + std_exp
# lower_bound = np.array(data_frame['v_init_per_n_ori_th_no_time_varying']) - std_exp
# ax.axhspan(upper_bound[0], lower_bound[0], facecolor='black', alpha=0.1)

ax.set(xlabel=r'$\lambda$ [h$^{-1}$]', ylabel=r'$v^\ast$ [$\mu$m$^3$]')
ax.set(ylim=(0,0.45))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
plt.savefig(file_path + '/Fig_3C_poster.pdf', format='pdf', bbox_inches='tight')

# %% [markdown]
# # Plot amplitude time varying

# %%
sns.set(style="ticks")
sns.set_context("poster")

fig, ax = plt.subplots(figsize=(7,4))
sns.lineplot(
    x='rate_growth', 
    y='amplitude_frac',
    data=data_frame.sort_values(by=["destruction_rate_datA"], ascending=False),
    hue='legend_datA',
    dashes=['', (4, 1)],
#     markers=True,
    palette= [green, blue,  pinkish_red], # yellow],
    style='model:',
    linewidth = 3.5,
    ax=ax
);
# ax.lines[0].set_linestyle("--")
# ax.lines[1].set_linestyle("--")
# ax.lines[2].set_linestyle("--")
# ax.lines[3].set_linestyle("--")
ax.margins(0)
ax.set(xlabel=r'$\lambda$ [h$^{-1}$]', ylabel=r'$\Delta f = f^\ast-f_{\rm min}$')
# plt.legend(labels=legend
ax.set(ylim=(0,0.8))
ax.tick_params(direction='out', length=6, width=2, grid_alpha=0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles=handles[1:], labels=labels[1:])
plt.savefig(file_path + '/Fig_3D.pdf', format='pdf', bbox_inches='tight')
